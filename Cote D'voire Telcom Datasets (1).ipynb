# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('Telcom_dataset.csv')
df
# Out:
#      PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
df2 = pd.read_csv('Telcom_dataset2.csv')
df2
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
#           DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
df3 = pd.read_csv('Telcom_dataset3.csv')
df3
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1        sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2      Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3        sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4      Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# ...

# %% [markdown]
# # Accessing information in table 1

# %%
df.info
# Out:
# <bound method DataFrame.info of      PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
# ...

# %%
df.isnull().sum()
# Out:
# PRODUTC              0
# VALUE                0
# DATETIME             0
# CELL_ON_SITE         0
# DW_A_NUMBER_INT      0
# DW_B_NUMBER_INT      0
# COUNTRY_A            0
# COUNTRY_B            0
# CELL_ID              0
# SITE_ID            716
# dtype: int64

# %%
df.dtypes
# Out:
# PRODUTC            object
# VALUE               int64
# DATETIME           object
# CELL_ON_SITE       object
# DW_A_NUMBER_INT    object
# DW_B_NUMBER_INT    object
# COUNTRY_A          object
# COUNTRY_B          object
# CELL_ID            object
# SITE_ID            object
# dtype: object

# %%
df.values
# Out:
# array([['Voice', 0, '2012-05-06 23:04:37.0', ..., '19e2e', '/TJNe+Mmtu',
#         '/TJNe+Mmtu'],
#        ['sms', 0, '2012-05-06 23:05:25.0', ..., '19e2e', '/+cKZKIp41',
#         '/+cKZKIp41'],
#        ['sms', 25, '2012-05-06 23:05:41.0', ..., '19e2e', '/u0FSD+ahi',
#         '/u0FSD+ahi'],
#        ...,
#        ['Voice', 0, '2012-05-07 00:01:54.0', ..., '19e2e', '7773627c12',
#         '9ef9616350'],
#        ['Voice', 0, '2012-05-07 00:01:54.0', ..., '19e2e', '3f4af49d6c',
#         '969b8d0e39'],
#        ['Voice', 7, '2012-05-07 00:01:54.0', ..., '19e2e', '6f4d9b77a5',
#         'ebfc58af70']], dtype=object)

# %%
df.drop_duplicates().any()
# Out:
# PRODUTC            True
# VALUE              True
# DATETIME           True
# CELL_ON_SITE       True
# DW_A_NUMBER_INT    True
# DW_B_NUMBER_INT    True
# COUNTRY_A          True
# COUNTRY_B          True
# CELL_ID            True
# SITE_ID            True
# dtype: bool

# %% [markdown]
# # Accessing information in table 2

# %%
df2.info
# Out:
# <bound method DataFrame.info of      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
# ...

# %%
df2.isnull().sum()
# Out:
# PRODUCT           0
# VALUE             0
# DATE_TIME         0
# CELL_ON_SITE      0
# DW_A_NUMBER       0
# DW_B_NUMBER       0
# COUNTRY_A         0
# COUNTRY_B         0
# CELL_ID           0
# SITE_ID         676
# dtype: int64

# %%
df2.values
# Out:
# array([['sms', 0, '2012-05-07 23:02:06.0', ..., '19e2e', '+854AcBQT2',
#         '+854AcBQT2'],
#        ['Voice', 0, '2012-05-07 23:03:44.0', ..., '19e2e', '+854AcBQT2',
#         '+854AcBQT2'],
#        ['sms', 0, '2012-05-07 23:04:06.0', ..., '19e2e', '+laSrk7g6q',
#         '+laSrk7g6q'],
#        ...,
#        ['sms', 0, '2012-05-08 00:01:53.0', ..., '19e2e', 'fe70e431df',
#         'c7ea989264'],
#        ['data', 0, '2012-05-08 00:01:53.0', ..., 'OTHER', 'ffa6759bb2',
#         nan],
#        ['Voice', 0, '2012-05-08 00:01:53.0', ..., '19e2e', '8630058aca',
#         'b47a998a3e']], dtype=object)

# %%
df2.dtypes
# Out:
# PRODUCT         object
# VALUE            int64
# DATE_TIME       object
# CELL_ON_SITE    object
# DW_A_NUMBER     object
# DW_B_NUMBER     object
# COUNTRY_A       object
# COUNTRY_B       object
# CELL_ID         object
# SITE_ID         object
# dtype: object

# %%
df2.drop_duplicates().any()
# Out:
# PRODUCT         True
# VALUE           True
# DATE_TIME       True
# CELL_ON_SITE    True
# DW_A_NUMBER     True
# DW_B_NUMBER     True
# COUNTRY_A       True
# COUNTRY_B       True
# CELL_ID         True
# SITE_ID         True
# dtype: bool

# %% [markdown]
# # Accessing information in table 3

# %%
df3.info
# Out:
# <bound method DataFrame.info of      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1        sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2      Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3        sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4      Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
# ...

# %%
df3.isnull().sum()
# Out:
# PRODUCT              0
# VALUE                0
# DATE_TIME            0
# CELL_ON_SITE         0
# DW_A_NUMBER_INT      0
# DW_B_NUMBER_INT      0
# COUNTRY_A            0
# COUNTRY_B            0
# CELLID               0
# SIET_ID            605
# dtype: int64

# %%
df3.values
# Out:
# array([['Voice', 61, '2012-05-08 23:01:28.0', ..., '19e2e', '+38u2u/rfx',
#         '+38u2u/rfx'],
#        ['sms', 0, '2012-05-08 23:01:31.0', ..., '19e2e', '+Fs4mTvdKx',
#         '+Fs4mTvdKx'],
#        ['Voice', 10, '2012-05-08 23:02:59.0', ..., '19e2e', '+ZaaZozy/+',
#         '+ZaaZozy/+'],
#        ...,
#        ['Voice', 32, '2012-05-09 00:01:43.0', ..., '19e2e', 'a4731e780e',
#         'd68260ef50'],
#        ['Voice', 30, '2012-05-09 00:01:43.0', ..., '19e2e', '98ed726da2',
#         'b4130b54ab'],
#        ['Voice', 60, '2012-05-09 00:01:43.0', ..., '19e2e', '1c11a2fcbb',
#         '6d70dae094']], dtype=object)

# %%
df3.dtypes
# Out:
# PRODUCT            object
# VALUE               int64
# DATE_TIME          object
# CELL_ON_SITE       object
# DW_A_NUMBER_INT    object
# DW_B_NUMBER_INT    object
# COUNTRY_A          object
# COUNTRY_B          object
# CELLID             object
# SIET_ID            object
# dtype: object

# %%
df3.drop_duplicates().any()
# Out:
# PRODUCT            True
# VALUE              True
# DATE_TIME          True
# CELL_ON_SITE       True
# DW_A_NUMBER_INT    True
# DW_B_NUMBER_INT    True
# COUNTRY_A          True
# COUNTRY_B          True
# CELLID             True
# SIET_ID            True
# dtype: bool

# %%
# from the above datasets we notice that the 3 datasets have the same column names though some of them are mispelled
# and need some cleaning
# we also notice that the three datasets have the same number of rows and columns
# The datasets also contain null values
# The datasets do not contain duplicate values
# Next we'll proceed to cleaning our datasets

# %% [markdown]
# # Data cleaning

# %% [markdown]
# # Table 1

# %%
df
# Out:
#      PRODUTC  VALUE               DATETIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
# Renaming columns
# Column name Produtc is mispelled and datetime needs to be spaced

df.rename(columns = {'PRODUTC':'PRODUCT','DATETIME':'DATE_TIME'}, inplace = True)

# %%
df
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
# There are many ways of filling in null values but in our case 
# the column site_id has 716 missing values which is a lot
# so we'll resort to dropping the whole column in which the case
# would be very different if we were to use that column for our analysis

df.drop('SITE_ID',axis = 1, inplace = True)

# %%
df
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996     sms    100  2012-05-07 00:01:54.0            0  92e367d671f45c5
# 4997   Voice      1  2012-05-07 00:01:54.0            1  83b44b18238e602
# 4998   Voice      0  2012-05-07 00:01:54.0            1  49fae048b547780
# 4999   Voice      0  2012-05-07 00:01:54.0            0  a1613f1a992716a
# 5000   Voice      7  2012-05-07 00:01:54.0            2  1670a5f7c22f4ed
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID
# ...

# %% [markdown]
# # Table 2

# %%
df2
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE      DW_A_NUMBER  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
#           DW_B_NUMBER COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
# Renaming column names in our table so that it is in line with the other datasets
df2.rename(columns = {'DW_A_NUMBER':'DW_A_NUMBER_INT','DW_B_NUMBER':'DW_B_NUMBER_INT'}, inplace = True)

# %%
df2
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
# The site_id had a lot of missing values so we are going to drop the column

df2.drop('SITE_ID', axis = 1, inplace = True)

# %%
df2
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0        sms      0  2012-05-07 23:02:06.0            2  32255675c3b6fe3
# 1      Voice      0  2012-05-07 23:03:44.0            1  ff16d6ac74c1c64
# 2        sms      0  2012-05-07 23:04:06.0            0  98d9f2fb5ff624b
# 3      Voice     37  2012-05-07 23:04:48.0            1  3f9c8a33ec7be1f
# 4        sms     25  2012-05-07 23:04:58.0            1  7bcccc03adf3864
# ...      ...    ...                    ...          ...              ...
# 4996     sms      0  2012-05-08 00:01:53.0            8  22ffbbb8ac8cde1
# 4997     sms     25  2012-05-08 00:01:53.0            0  bcf512a3542d42c
# 4998     sms      0  2012-05-08 00:01:53.0            0  05e3c3d41628a9f
# 4999    data      0  2012-05-08 00:01:53.0            _  86a4dbf018f6f24
# 5000   Voice      0  2012-05-08 00:01:53.0            0  a03c9837c62a5b9
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID
# ...

# %% [markdown]
# # Table 3

# %%
df3
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1        sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2      Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3        sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4      Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B      CELLID     SIET_ID
# ...

# %%
# Renaming our columns

df3.rename(columns = {'CELLID':'CELL_ID','SIET_ID':'SITE_ID'}, inplace = True)

# %%
df3
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1        sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2      Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3        sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4      Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID
# ...

# %%
# Droping columns that have a lot of missing values

df3.drop('SITE_ID', axis = 1, inplace = True)

# %%
df3
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice     61  2012-05-08 23:01:28.0            2  966f68353622feb
# 1        sms      0  2012-05-08 23:01:31.0            1  a0a597384c612d7
# 2      Voice     10  2012-05-08 23:02:59.0            1  5441a9a58c97132
# 3        sms      0  2012-05-08 23:03:04.0            0  8ab8b9ed6989f61
# 4      Voice     22  2012-05-08 23:03:16.0            4  52662a62b199334
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID
# ...

# %% [markdown]
# # Merging of tables 1,2,3

# %%
# Merging our datasets making it easier for doing analysis
frames = [df, df2, df3]

result = pd.concat(frames)

# %%
result
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4998   Voice     32  2012-05-09 00:01:43.0            1  77f53c39d27c050
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID
# ...

# %% [markdown]
# # CDR DESCRIPTION

# %%
import warnings
warnings.simplefilter(action = 'ignore', category = Warning)

# %%
# Loading our description dataset, cleaning and previewing it
cells_geo = pd.read_csv('cells_geo.csv',index_col=0,sep=r'[;]')
cells_geo
# Out:
#         VILLES      STATUS LOCALISATION       DECOUPZONE             ZONENAME  \
# 0       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 1       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 2       ADJAME  In Service      ABIDJAN  """Abidjan_EST"             AGBANNEW
# 3      ASSINIE  In Service    INTERIEUR        Grand-EST          "ASSINIE"""
# 4      ASSINIE  In Service    INTERIEUR        Grand-EST          "ASSINIE"""
# ...        ...         ...          ...              ...                  ...
# 3969  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3970  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3971  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3972  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
# 3973  ZUENOULA  In Service    INTERIEUR       Grand-NORD  ZONE A - Grand-NORD
#
# ...

# %%
# dropping empty columns
cells_geo = cells_geo.dropna(axis=0,how='any')
# dropping duplicates
cells_geo.drop_duplicates(keep=False,inplace=True)
cells_geo
# Out:
#         VILLES      STATUS LOCALISATION    DECOUPZONE               ZONENAME  \
# 23       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 24       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 25       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 26       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# 27       ABOBO  In Service      ABIDJAN  Abidjan_NORD  ZONE E - Abidjan_NORD
# ...        ...         ...          ...           ...                    ...
# 3969  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3970  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3971  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3972  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
# 3973  ZUENOULA  In Service    INTERIEUR    Grand-NORD    ZONE A - Grand-NORD
#
# ...

# %%
# loading our cell geo description dataset
cells_geo_description = pd.read_excel('cells_geo_description.xlsx')
cells_geo_description
# Out:
#      Column name                                        Description  Format
# 0         VILLES                                               City  String
# 1         STATUS                                  In Service or not  String
# 2   LOCALISATION                                  in ABIDJAN or not  String
# 3     DECOUPZONE                                  Geographical Zone  String
# 4       ZONENAME                                       Name of Zone  String
# 5      LONGITUDE                                          Longitude   Float
# 6       LATITUDE                                           Latitude   Float
# 7         REGION                                             Region  String
# 8           AREA                                               Area  String
# 9        CELL_ID                                     ID of the cell  String
# 10     SITE_CODE  Site (there are several cells per site, severa...  String

# %%
# checking cell geo data types
cells_geo.dtypes
# Out:
# VILLES           object
# STATUS           object
# LOCALISATION     object
# DECOUPZONE       object
# ZONENAME         object
# LONGITUDE       float64
# LATITUDE        float64
# REGION           object
# AREA             object
# CELL_ID          object
# SITE_CODE        object
# dtype: object

# %%
# converting our data types to the required form in the description
cells_geo['VILLES']=cells_geo['VILLES'].astype('string')
cells_geo['STATUS']=cells_geo['STATUS'].astype('string')
cells_geo['LOCALISATION']=cells_geo['LOCALISATION'].astype('string')
cells_geo['DECOUPZONE']=cells_geo['DECOUPZONE'].astype('string')
cells_geo['ZONENAME']=cells_geo['ZONENAME'].astype('string')
cells_geo['REGION']=cells_geo['REGION'].astype('string')
cells_geo['AREA']=cells_geo['AREA'].astype('string')
cells_geo['CELL_ID']=cells_geo['CELL_ID'].astype('string')
cells_geo['SITE_CODE']=cells_geo['SITE_CODE'].astype('string')

# %%
# update after conversion
cells_geo.dtypes
# Out:
# VILLES           string
# STATUS           string
# LOCALISATION     string
# DECOUPZONE       string
# ZONENAME         string
# LONGITUDE       float64
# LATITUDE        float64
# REGION           string
# AREA             string
# CELL_ID          string
# SITE_CODE        string
# dtype: object

# %% [markdown]
# # merging of telcom dataset and the cells geo

# %%
New_df = result.merge(cells_geo,left_index=True,right_index=True,copy=True)
New_df
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 23      data      0  2012-05-06 23:11:27.0            _  795c2a90bd8d442
# 23       sms      0  2012-05-07 23:09:50.0            1  8da7870ee027a39
# 23       sms     25  2012-05-08 23:09:48.0            2  711a413770e5028
# 24     Voice      0  2012-05-06 23:11:27.0            1  1a2b54695968d46
# 24       sms      0  2012-05-07 23:09:56.0            1  0108b4b998a2041
# ...      ...    ...                    ...          ...              ...
# 3972   Voice     34  2012-05-08 00:01:25.0            1  f90739859eb4852
# 3972     sms     25  2012-05-09 00:01:16.0            0  ef07327c65f5dd6
# 3973   Voice     40  2012-05-07 00:01:26.0            5  6aa773f400a4b1b
# 3973   Voice      0  2012-05-08 00:01:25.0            0  474bdfd8355e807
# 3973     sms      0  2012-05-09 00:01:16.0            2  ba8211884915c7a
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B   CELL_ID_x    VILLES      STATUS  \
# ...

# %%
# DROPPING COLUMNS THAT ARE NOT IMPORTANT FOR ANALYSIS

New_df.drop(['COUNTRY_A','COUNTRY_B','CELL_ON_SITE'],axis=1, inplace=True)
New_df
# Out:
#      PRODUCT  VALUE              DATE_TIME  DW_A_NUMBER_INT  DW_B_NUMBER_INT  \
# 23      data      0  2012-05-06 23:11:27.0  795c2a90bd8d442  5a4dc9e82deb309
# 23       sms      0  2012-05-07 23:09:50.0  8da7870ee027a39  43856ca73fbadf3
# 23       sms     25  2012-05-08 23:09:48.0  711a413770e5028  fc1e25118646138
# 24     Voice      0  2012-05-06 23:11:27.0  1a2b54695968d46  55ad144fa74fddc
# 24       sms      0  2012-05-07 23:09:56.0  0108b4b998a2041  8051dc22ab2d575
# ...      ...    ...                    ...              ...              ...
# 3972   Voice     34  2012-05-08 00:01:25.0  f90739859eb4852  1a465a6dbbcd519
# 3972     sms     25  2012-05-09 00:01:16.0  ef07327c65f5dd6  70623567ff7a06c
# 3973   Voice     40  2012-05-07 00:01:26.0  6aa773f400a4b1b  88dd51e4d6885f0
# 3973   Voice      0  2012-05-08 00:01:25.0  474bdfd8355e807  4571828cc5decad
# 3973     sms      0  2012-05-09 00:01:16.0  ba8211884915c7a  15f397ecd43dcba
#
# ...

# %%
New_df = result.dropna(axis=0,how='any')

New_df.drop_duplicates(keep=False,inplace=True)
New_df
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0      Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1        sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2        sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3      Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4      Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...      ...    ...                    ...          ...              ...
# 4995   Voice     10  2012-05-09 00:01:43.0            0  2f834987f0c1825
# 4996   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 4997   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 4999   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 5000   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID
# ...

# %%
New_df['DATE'] = pd.to_datetime(New_df['DATE_TIME']).dt.date
New_df['TIME'] = pd.to_datetime(New_df['DATE_TIME']).dt.time

# %%
New_df
# Out:
#      PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 23      data      0  2012-05-06 23:11:27.0            _  795c2a90bd8d442
# 23       sms      0  2012-05-07 23:09:50.0            1  8da7870ee027a39
# 23       sms     25  2012-05-08 23:09:48.0            2  711a413770e5028
# 24     Voice      0  2012-05-06 23:11:27.0            1  1a2b54695968d46
# 24       sms      0  2012-05-07 23:09:56.0            1  0108b4b998a2041
# ...      ...    ...                    ...          ...              ...
# 3972   Voice     34  2012-05-08 00:01:25.0            1  f90739859eb4852
# 3972     sms     25  2012-05-09 00:01:16.0            0  ef07327c65f5dd6
# 3973   Voice     40  2012-05-07 00:01:26.0            5  6aa773f400a4b1b
# 3973   Voice      0  2012-05-08 00:01:25.0            0  474bdfd8355e807
# 3973     sms      0  2012-05-09 00:01:16.0            2  ba8211884915c7a
#
#       DW_B_NUMBER_INT COUNTRY_A COUNTRY_B   CELL_ID_x    VILLES  ...  \
# ...

# %% [markdown]
# # Data Analysis

# %%
New_df['PRODUCT'].value_counts()
# Out:
# sms      6829
# Voice    5474
# data     2194
# Name: PRODUCT, dtype: int64

# %%
#which product was was most and less used in what country

New_df[New_df['PRODUCT'] == 'sms']['VILLES'].value_counts()
# Out:
# COCODY         508
# YOPOUGON       372
# ABOBO          353
# MARCORY        195
# TREICHVILLE    188
#               ...
# GAZIBOUO         1
# BOTRO            1
# SOROBANGO        1
# KOUIBLY          1
# NAMBENGUE        1
# Name: VILLES, Length: 473, dtype: Int64

# %%
# on what day was the most product used
New_df.loc[New_df['PRODUCT'] == 'sms',['PRODUCT','DATE']].max()
# Out:
# PRODUCT           sms
# DATE       2012-05-09
# dtype: object

# %%
# CITIES THAT WERE MOSTLY USED IN THE THREE DAYS

New_df.groupby(["VILLES"])["VALUE"].count().sort_values(ascending=False)
# Out:
# VILLES
# COCODY         1056
# YOPOUGON        849
# ABOBO           732
# MARCORY         417
# TREICHVILLE     396
#                ...
# KRIKOREA          6
# MEMNI             6
# KOTOULA           6
# OUANGOLO          3
# DANANON           3
# Name: VALUE, Length: 501, dtype: int64

# %%
pivot=pd.pivot_table(New_df,values=['VALUE'],index=['PRODUCT'],aggfunc='sum')
pivot.sort_values('VALUE',ascending=False)
# Out:
#           VALUE
# PRODUCT
# Voice    244356
# sms       43151
# data      14568

# %%
# Areas that uses the product mostly
New_df.groupby(["AREA"])["PRODUCT"].count().sort_values(ascending=False)
# Out:
# AREA
# ABIDJAN NORTH    3534
# ABIDJAN SOUTH    1905
# CENTRE NORTH     1827
# NORTH WEST       1683
# SOUTH WEST       1593
# EAST             1002
# Name: PRODUCT, dtype: int64

# %%
New_df.nunique()
# Out:
# PRODUCT               3
# VALUE               335
# DATE_TIME          1955
# CELL_ON_SITE          8
# DW_A_NUMBER_INT    8566
# DW_B_NUMBER_INT    6625
# COUNTRY_A             1
# COUNTRY_B             2
# CELL_ID_x          2421
# VILLES              501
# STATUS                1
# LOCALISATION          2
# DECOUPZONE           11
# ZONENAME             25
# LONGITUDE          1006
# LATITUDE           1015
# REGION               19
# AREA                  6
# CELL_ID_y          3845
# SITE_CODE          1021
# DATE                  4
# TIME               1468
# dtype: int64
